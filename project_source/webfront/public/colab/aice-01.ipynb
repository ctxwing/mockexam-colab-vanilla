# %% [markdown]
# # AICE 실기 모의고사 1회 정답 및 해설
#
# 본 해설은 AICE Associate 샘플 문항을 바탕으로 작성되었습니다.
# 내비게이션 주행 데이터를 분석하여 목적지 도착 시간을 예측하는 태스크를 다룹니다.
#
# <div style="background-color: #3B82F6; color: white; padding: 12px 20px; border-radius: 12px; display: flex; align-items: center; gap: 16px; font-family: sans-serif; margin: 24px 0; box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1);">
#   <div style="background-color: #1D4ED8; padding: 6px 14px; border-radius: 8px; display: flex; align-items: center; gap: 8px; font-weight: bold; flex-shrink: 0; font-size: 14px;">
#     참고 링크
#   </div>
#   <div style="flex-grow: 1; font-family: monospace; font-size: 14px; overflow: hidden; text-overflow: ellipsis; white-space: nowrap; opacity: 0.9;">
#     https://velog.io/@junseyeon/AICE-associate-%EC%83%98%ED%94%8C%EB%AC%B8%ED%95%AD-%ED%92%80%EC%9D%B4
#   </div>
# </div>
#
# ---
#
# ## 📋 [Part 1] 데이터 탐색 및 전처리
#
# ### 1. 데이터 로드 및 시각화
# 주행 데이터(`A0007IT.json`)를 로드하고 주요 변수의 분포를 확인합니다.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_json('https://raw.githubusercontent.com/venture21/AICE-associate/main/AICE%20Associate%20A0007IT.json')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 2. 데이터 정제 (Cleaning)
# 이상치와 결측치를 처리합니다.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 3. 피처 엔지니어링
# 모델 학습에 불필요한 컬럼을 제거하고 범주형 변수를 인코딩합니다.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 🤖 [Part 2] 머신러닝 모형 구축
#
# ### 4. 의사결정나무(Decision Tree) 예측
# 도착 시간(Regression)을 예측하는 모델을 학습합니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 🧠 [Part 3] 딥러닝 모형 구축
#
# ### 5. MLP(Multi-Layer Perceptron) 모델
# TensorFlow/Keras를 사용하여 신경망 모델을 구축합니다.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# 여기에 코드를 작성하세요
