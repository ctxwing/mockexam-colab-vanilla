# %% [markdown]
# # 제10회 빅데이터 분석기사 실기 모의고사 정답 및 해설
#
# 본 해설은 빅데이터분석기사 – 기출문제 10회 (2025.06.21) 문제를 바탕으로 작성되었습니다.
# 데이터셋은 아래의 레포지토리를 기준으로 합니다.
#
# <div style="background-color: #E24A3B; color: white; padding: 12px 20px; border-radius: 12px; display: flex; align-items: center; gap: 16px; font-family: sans-serif; margin: 24px 0; box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1);">
#   <div style="background-color: #8B1A10; padding: 6px 14px; border-radius: 8px; display: flex; align-items: center; gap: 8px; font-weight: bold; flex-shrink: 0; font-size: 14px;">
#     <span style="font-size: 18px;">git</span> 데이터셋 경로
#   </div>
#   <div style="flex-grow: 1; font-family: monospace; font-size: 14px; opacity: 0.9;">
#     https://raw.githubusercontent.com/YoungjinBD/data/main/exam/
#   </div>
# </div>
#
# ---
#
# ## 📋 [작업형 제 1유형] 데이터 전처리
#
# ### Q1. 소주제별 정답률 분석
# **문제**: 소주제별(`sub_topic`) 정답률(정답여부가 1인 응답 수 / 해당 소주제 전체 응답 수)을 구하고, 3번째로 높은 정답률을 구하시오. (동일 정답률은 하나의 순위로 간주, 소수점 둘째자리 반올림)
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_1.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_1.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_1.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q2. 연도-월별 매출 및 카테고리 분석
# **문제**: `date`를 연도/월로 분리하여 매출액 합계를 구하고 두 번째로 큰 매출액을 출력하시오. 또한 네 번째로 큰 매출액의 연도-월에서 가장 높은 카테고리별 매출 합계를 구하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_2.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_2.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_2.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q3. 스팸/햄 평균 단어 수 차이
# **문제**: `message`의 단어 수를 공백 기준으로 세고, `spam`과 `ham`의 평균 단어 수 차이의 절댓값을 소수점 셋째자리까지 구하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_3.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_3.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_1_3.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 🤖 [작업형 제 2유형] 모델 구축
#
# ### Q4. 가스 소비량(gas_totl) 예측 (Regression)
# **문제**: 건물의 상권 유형, 면적, 연식 등을 바탕으로 연간 총 가스 소비량을 예측하는 모델을 만드시오. (평가지표: RMSE)
#
# - **훈련 데이터**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_2_train.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_2_train.csv)
# - **테스트 데이터**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_2_test.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_2_test.csv)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
train = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_2_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_2_test.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 📊 [작업형 제 3유형] 통계적 가설 검정
#
# ### Q5. 로지스틱 회귀: 회귀계수 및 오즈비
# **문제**: 이직 여부 예측 모델에서 유의한 변수의 회귀계수, 나이 증가에 따른 오즈비, 특정 조건의 이직 확률을 구하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_3_1.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_3_1.csv)

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_3_1.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q6. 다중선형회귀: 주택 가격 예측
# **문제**: 주택 가격 예측 모델 적합 후 유의한 변수의 회귀계수 합, 결정계수, 특정 조건의 예측 가격을 구하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_3_2.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_3_2.csv)

# %%
import statsmodels.api as sm
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/10_3_2.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 최종 결과 제출
# 모든 문제의 답을 구한 뒤, 구글 설문지에 답안을 입력하세요.
