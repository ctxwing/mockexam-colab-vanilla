# %% [markdown]
# # 제7회 빅데이터 분석기사 실기 복원 모의고사 정답 및 해설
#
# 본 해설은 빅데이터분석기사 – 기출문제 7회 (2023.12.02) 문제를 바탕으로 작성되었습니다.
# 데이터셋은 아래의 레포지토리를 기준으로 합니다.
#
# <div style="background-color: #E24A3B; color: white; padding: 12px 20px; border-radius: 12px; display: flex; align-items: center; gap: 16px; font-family: sans-serif; margin: 24px 0; box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1);">
#   <div style="background-color: #8B1A10; padding: 6px 14px; border-radius: 8px; display: flex; align-items: center; gap: 8px; font-weight: bold; flex-shrink: 0; font-size: 14px;">
#     <span style="font-size: 18px;">git</span> 데이터셋 경로
#   </div>
#   <div style="flex-grow: 1; font-family: monospace; font-size: 14px; opacity: 0.9;">
#     https://raw.githubusercontent.com/YoungjinBD/data/main/exam/
#   </div>
# </div>
#
# ---
#
# ## 📋 [작업형 제 1유형] 데이터 전처리
#
# ### Q1. 공장별 평균 처리시간 분석
# **문제**: `07_1_1.csv` 데이터에서 공장별(`Factory`) 평균 처리시간(`Processing_Time`)을 소수점 둘째 자리까지 반올림하여 계산하고, 평균 처리시간이 가장 짧은 공장 3곳의 이름을 리스트로 출력하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_1.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_1.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_1.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q2. 구별 평균 이동거리 비교
# **문제**: `Address` 컬럼에서 '구' 단위를 추출하여 새로운 컬럼을 만들고, '마포구'와 '성동구'의 평균 이동거리(`Distance`) 차이의 절댓값을 소수점 둘째 자리까지 구하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_2.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_2.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_2.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q3. 매출액 최고 연도 및 분기
# **문제**: `07_1_3.csv` 데이터를 이용하여 연도 및 분기별 총 매출액의 합계를 구하고, 가장 매출이 높았던 연도와 분기(`(Year, Quarter)`)를 출력하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_3.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_3.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_1_3.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 🤖 [작업형 제 2유형] 모델 구축
#
# ### Q4. 학생 상태 분류 모델 (Multi-class Classification)
# **문제**: 학생 데이터를 바탕으로 `Target` 컬럼(Dropout, Enrolled, Graduate)을 예측하는 모델을 만드시오. (평가지표: Macro F1-score)
#
# - **훈련 데이터**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_2_train.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_2_train.csv)
# - **테스트 데이터**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_2_test.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_2_test.csv)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
train = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_2_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/07_2_test.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 📊 [작업형 제 3유형] 통계적 가설 검정
#
# ### Q5. 기초 통계량 확인
# **문제**: 학습 프로그램 적용 전(`pre`) 시험 점수의 평균과 표준편차를 소수점 둘째 자리까지 구하시오.
#
# - **데이터셋**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_1.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_1.csv)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_1.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q6. 대응표본 t-검정: 통계량
# **문제**: 대응표본 t-검정을 수행하고, 검정통계량(t-statistic)을 소수점 둘째 자리까지 구하시오.

# %%
from scipy import stats
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q7. 귀무가설 기각 여부
# **문제**: 유의수준 5%에서 귀무가설 기각 여부를 결정하시오. (p-value 기준)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q8. 로지스틱 회귀: 오즈비(Odds Ratio)
# **문제**: 'Income' 변수의 오즈비(Odds Ratio)를 소수점 둘째 자리까지 구하시오.
#
# - **훈련 데이터**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_2_train.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_2_train.csv)

# %%
import statsmodels.api as sm
import numpy as np
train = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_2_train.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q9. 잔차 이탈도 (Residual Deviance)
# **문제**: 구축한 로지스틱 회귀 모델의 잔차 이탈도를 소수점 둘째 자리까지 구하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### Q10. 오분류율 (Error Rate)
# **문제**: 테스트 데이터를 사용하여 모델의 오분류율을 소수점 둘째 자리까지 구하시오.
#
# - **테스트 데이터**: [https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_2_test.csv](https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_2_test.csv)

# %%
from sklearn.metrics import accuracy_score
test = pd.read_csv('https://raw.githubusercontent.com/YoungjinBD/data/main/exam/7_3_2_test.csv')
# 여기에 코드를 작성하세요

# %% [markdown]
# ---

# %% [markdown]
# ## 최종 결과 제출
# 모든 문제의 답을 구한 뒤, 구글 설문지에 답안을 입력하세요.
